# %% [markdown]
# # Decision Tree Regression

# %% [markdown]
# Decision tree have 2 form, classification tree & regression tree <br>
# This section specific on regression tree <br>
# <br>
# Imagine diagram x1 x2 and y, decision tree splitting scatter to several area.<br>
# (study information entropy)<br>
# <br>
# Decision tree split scatter in several place, example:<br>
# 1. x1<20, if yes 2, if no 3<br>
# 2. x2<200, if yes 4, if no 5<br>
# 3. x2<179, if yes 6 if no 7<br>
# 4.<br>
# 5.<br>
# 6.x1<10, if yes 8, if no 9<br>
# 7.<br>
# 8.<br>
# 9.<br>
# <br>
# if some value predicted get on some area, to predict y we need the y value of all variable in that area, and get y by calculate the mean of all variable's y value in that area.

# %% [markdown]
# ## Importing the libraries

# %% [markdown]
# ## Importing the dataset

# %% [markdown]
# ## Training the Decision Tree Regression model on the whole dataset

# %% [markdown]
# ## Predicting a new result

# %% [markdown]
# ## Visualising the Decision Tree Regression results (higher resolution)
